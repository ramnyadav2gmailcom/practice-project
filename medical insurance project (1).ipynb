# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:/Users/USER/Downloads/medical_cost_insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# this datasets contain the 1338 row and 7 columns.one is target column.

# %%
 df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# This datesets give infomation about the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# This datasets gives the infomation about the data.my datasest contains the integer float and object type data

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# datasets contain not any null value

# %%
# finding null value through the visulisation
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# high standard deviation are present in age and bmi column means bmi columns data is sprading and range is high
# in age and bmi column mean is greater than median means data is skewed to right side
# large gap between the 75th percentile and max in age,bmi and children hence outlier are present

# %%
df.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %%
ax=sns.countplot(data=df,x='sex')
print(df['sex'].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# this datasets contain the 676 male value and 662 female value

# %%
ax=sns.countplot(x='smoker',data=df)
print(df['smoker'].value_counts())
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# this datasets contain smoker column which is imbalance datasets

# %%
sns.countplot(x="region",data=df)
print(df['region'].value_counts())
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# this graph and value show dataset is almost equal

# %%
ax=sns.countplot(x='children',data=df)
print(df['children'].value_counts())
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.displot(x='bmi',data=df)
plt.title('bmi distribution')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.displot(x='age',data=df)
plt.title("age distribution")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.displot(x='charges',data=df)
plt.title('charges distribution')
plt.show()

# %%
sns.hisplot(data=df,'bmi')
# Out:
#   Cell In[52], line 1
#     sns.hisplot(data=df,'bmi')
#                              ^
# SyntaxError: positional argument follows keyword argument

# %%
df['bmi'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['charges'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['children'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot('bmi',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df.boxplot('bmi',data=df)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:516, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     499 @Substitution(backend=_backend_doc)
#     500 @Appender(_boxplot_doc)
#     501 def boxplot_frame(
#    (...)
#     513     **kwargs,
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#     519         by=by,
#     520         ax=ax,
#     521         fontsize=fontsize,
#     522         rot=rot,
#     523         grid=grid,
#     524         figsize=figsize,
#     525         layout=layout,
#     526         return_type=return_type,
#     527         **kwargs,
# ...

# %%
sns.pairplot(data=df)

# %%
#detecting outlier with the help of boxplot

# %%
df['bmi'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# this boxplot show bmi column contain the outlier

# %%
df['age'].plot.box()
# Out:
# <Axes: >

# %%
df['children'].plot.box()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# high standard deviation present in age and bmi means data is sprad too much high.mean is greater than median in age,bmi means data is skewed rightside.larage gap between 75% and maximum in age,bmi hence outlier are present

# %%
 df['charges'].plot.box()
# Out:
# <Axes: >

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0     1.438764  1.010519  0.453320  0.908614  1.970587  1.343905  0.298584
# 1     1.509965  0.989591  0.509621  0.078767  0.507463  0.438495  0.953689
# 2     0.797954  0.989591  0.383307  1.580926  0.507463  0.438495  0.728675
# 3     0.441948  0.989591  1.305531  0.908614  0.507463  0.466915  0.719843
# 4     0.513149  0.989591  0.292556  0.908614  0.507463  0.466915  0.776802
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926  0.507463  0.466915  0.220551
# 1334  1.509965  1.010519  0.206139  0.908614  0.507463  1.372326  0.914002
# 1335  1.509965  1.010519  1.014878  0.908614  0.507463  0.438495  0.961596
# 1336  1.296362  1.010519  0.797813  0.908614  0.507463  1.343905  0.930362
# 1337  1.551686  1.010519  0.261388  0.908614  1.970587  0.466915  1.311053
#
# [1338 rows x 7 columns]

# %%
#encoding the catagorical column using the labelencoder
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
#encoding the sex columns
df['sex']=le.fit_transform(df['sex'])

# %%
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    0  27.900         0    yes  southwest  16884.92400
# 1      18    1  33.770         1     no  southeast   1725.55230
# 2      28    1  33.000         3     no  southeast   4449.46200
# 3      33    1  22.705         0     no  northwest  21984.47061
# 4      32    1  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    1  30.970         3     no  northwest  10600.54830
# 1334   18    0  31.920         0     no  northeast   2205.98080
# 1335   18    0  36.850         0     no  southeast   1629.83350
# 1336   21    0  25.800         0     no  southwest   2007.94500
# 1337   61    0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df["smoker"]=le.fit_transform(df["smoker"])

# %%
df["region"]=le.fit_transform(df["region"])

# %% [markdown]
# we have encode the categoroical column

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
corr_hmap=df.corr()
plt.figure(figsize=(6,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
#spliting the independent and target column
x=df.drop(columns="charges",axis=1)

# %%
y=df.charges

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
x.shape
# Out:
# (1338, 6)

# %%
y.shape
# Out:
# (1338,)

# %% [markdown]
# x variable contain the 1338 rows and 6 columns and y variable only contain 1338 rows

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
#spliting the data x variable  and y variable
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
x_train.shape
# Out:
# (936, 6)

# %%
y_train.shape
# Out:
# (936,)

# %%
x_test.shape
# Out:
# (402, 6)

# %%
y_test.shape
# Out:
# (402,)

# %%
lmr=LinearRegression()

# %%
lmr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lmr.coef_
# Out:
# array([  261.62568984,   109.64719595,   344.54483066,   424.37016596,
#        23620.80252148,  -326.46262527])

# %%
lmr.score(x_train,y_train)
# Out:
# 0.74225713201721

# %%
# predict thevalue
pred=lmr.predict(x_test)

# %%
print("predicted reult price:",pred)
print("actual price:",y_test)
# Out:
# predicted reult price: [ 8.93142116e+03  7.07090670e+03  3.69370805e+04  9.59699214e+03
#   2.70083549e+04  1.08664849e+04  3.74610217e+01  1.72228092e+04
#   9.18308115e+02  1.13965537e+04  2.79154456e+04  9.53381323e+03
#   5.18928014e+03  3.86124990e+04  4.05094490e+04  3.72748566e+04
#   1.53562559e+04  3.59449407e+04  9.10631783e+03  3.14429410e+04
#   3.66298253e+03  1.00966745e+04  2.21091896e+03  7.10598084e+03
#   1.13521417e+04  1.30231210e+04  1.44472857e+04  6.12031303e+03
#   9.94564893e+03  2.18617424e+03  8.91389260e+03  1.31869496e+04
#   4.49110116e+03  3.30469662e+03  4.32885102e+03  1.32330189e+04
#   1.67071398e+03  8.63238607e+03  3.32727214e+04  3.26840062e+04
#   3.60294190e+03  4.40040903e+03  1.40663345e+04  1.16268203e+04
#   8.89219642e+03  1.21011367e+04  5.23906853e+03  2.84241293e+03
#   3.56294259e+04  9.27854339e+03  1.59720792e+04  2.34524488e+03
#   1.24695907e+04  1.45575199e+03  1.36060478e+04  1.27386152e+04
# ...

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 0.7694415927057693

# %%
#predict the insurance cost by providing the val
t=np.array([19,0,27.900,0,1,3])

# %%
t
# Out:
# array([19. ,  0. , 27.9,  0. ,  1. ,  3. ])

# %%
t=t.reshape(1,-1)

# %%
lmr.predict(t)
# Out:
# array([24860.7122057])

# %%
t=np.array([31,1,25.74,0,1,0])

# %%
t=t.reshape(1,-1)

# %%
lmr.predict(t)
# Out:
# array([28345.03872136])

# %%
import joblib

# %%
#save the model
joblib.dump(lmr,"lmrfile.obj")
# Out:
# ['lmrfile.obj']

# %%
#load the model
mylmrmodel=joblib.load("lmrfile.obj")
mylmrmodel.predict(x_test)
# Out:
# array([ 8.93142116e+03,  7.07090670e+03,  3.69370805e+04,  9.59699214e+03,
#         2.70083549e+04,  1.08664849e+04,  3.74610217e+01,  1.72228092e+04,
#         9.18308115e+02,  1.13965537e+04,  2.79154456e+04,  9.53381323e+03,
#         5.18928014e+03,  3.86124990e+04,  4.05094490e+04,  3.72748566e+04,
#         1.53562559e+04,  3.59449407e+04,  9.10631783e+03,  3.14429410e+04,
#         3.66298253e+03,  1.00966745e+04,  2.21091896e+03,  7.10598084e+03,
#         1.13521417e+04,  1.30231210e+04,  1.44472857e+04,  6.12031303e+03,
#         9.94564893e+03,  2.18617424e+03,  8.91389260e+03,  1.31869496e+04,
#         4.49110116e+03,  3.30469662e+03,  4.32885102e+03,  1.32330189e+04,
#         1.67071398e+03,  8.63238607e+03,  3.32727214e+04,  3.26840062e+04,
#         3.60294190e+03,  4.40040903e+03,  1.40663345e+04,  1.16268203e+04,
#         8.89219642e+03,  1.21011367e+04,  5.23906853e+03,  2.84241293e+03,
# ...
